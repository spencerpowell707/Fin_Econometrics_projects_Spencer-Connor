# %%
##Simulate random data for the spot & futures prices
##(replace this with spot & futures data)

# %%
import StatsKit
import CSV

# %%
import StatsPlots
import DataFrames

# %%
using GLM

# %%
futures = CSV.read("futures_data.csv")
# Out:
# 8470×2 DataFrame
# │ Row  │ Date      │ HO-Futures │
# │      │ String    │ Float64    │
# ├──────┼───────────┼────────────┤
# │ 1    │ 6/2/1986  │ 0.378      │
# │ 2    │ 6/3/1986  │ 0.38       │
# │ 3    │ 6/4/1986  │ 0.358      │
# │ 4    │ 6/5/1986  │ 0.374      │
# │ 5    │ 6/6/1986  │ 0.372      │
# │ 6    │ 6/9/1986  │ 0.366      │
# │ 7    │ 6/10/1986 │ 0.36       │
# │ 8    │ 6/11/1986 │ 0.384      │
# │ 9    │ 6/12/1986 │ 0.394      │
# │ 10   │ 6/13/1986 │ 0.397      │
# ⋮
# │ 8460 │ 2/18/2020 │ 1.672      │
# │ 8461 │ 2/19/2020 │ 1.707      │
# │ 8462 │ 2/20/2020 │ 1.698      │
# │ 8463 │ 2/21/2020 │ 1.687      │
# │ 8464 │ 2/24/2020 │ 1.613      │
# │ 8465 │ 2/25/2020 │ 1.569      │
# │ 8466 │ 2/26/2020 │ 1.499      │
# │ 8467 │ 2/27/2020 │ 1.489      │
# │ 8468 │ 2/28/2020 │ 1.491      │
# │ 8469 │ 3/2/2020  │ 1.529      │
# │ 8470 │ 3/3/2020  │ 1.533      │

# %%
spot = CSV.read("HO-Spot.csv")
# Out:
# 8497×2 DataFrame
# │ Row  │ Date      │ HO-Spot │
# │      │ String    │ Float64 │
# ├──────┼───────────┼─────────┤
# │ 1    │ 6/2/1986  │ 0.402   │
# │ 2    │ 6/3/1986  │ 0.393   │
# │ 3    │ 6/4/1986  │ 0.378   │
# │ 4    │ 6/5/1986  │ 0.39    │
# │ 5    │ 6/6/1986  │ 0.385   │
# │ 6    │ 6/9/1986  │ 0.373   │
# │ 7    │ 6/10/1986 │ 0.365   │
# │ 8    │ 6/11/1986 │ 0.389   │
# │ 9    │ 6/12/1986 │ 0.394   │
# │ 10   │ 6/13/1986 │ 0.398   │
# ⋮
# │ 8487 │ 2/10/2020 │ 1.581   │
# │ 8488 │ 2/12/2020 │ 1.647   │
# │ 8489 │ 2/13/2020 │ 1.651   │
# │ 8490 │ 2/14/2020 │ 1.669   │
# │ 8491 │ 2/17/2020 │ 1.669   │
# │ 8492 │ 2/18/2020 │ 1.644   │
# │ 8493 │ 2/19/2020 │ 1.667   │
# │ 8494 │ 2/20/2020 │ 1.657   │
# │ 8495 │ 2/21/2020 │ 1.65    │
# │ 8496 │ 2/24/2020 │ 1.575   │
# │ 8497 │ 2/25/2020 │ 1.529   │

# %%
futures
# Out:
# 8470×2 DataFrame
# │ Row  │ Date      │ HO-Futures │
# │      │ String    │ Float64    │
# ├──────┼───────────┼────────────┤
# │ 1    │ 6/2/1986  │ 0.378      │
# │ 2    │ 6/3/1986  │ 0.38       │
# │ 3    │ 6/4/1986  │ 0.358      │
# │ 4    │ 6/5/1986  │ 0.374      │
# │ 5    │ 6/6/1986  │ 0.372      │
# │ 6    │ 6/9/1986  │ 0.366      │
# │ 7    │ 6/10/1986 │ 0.36       │
# │ 8    │ 6/11/1986 │ 0.384      │
# │ 9    │ 6/12/1986 │ 0.394      │
# │ 10   │ 6/13/1986 │ 0.397      │
# ⋮
# │ 8460 │ 2/18/2020 │ 1.672      │
# │ 8461 │ 2/19/2020 │ 1.707      │
# │ 8462 │ 2/20/2020 │ 1.698      │
# │ 8463 │ 2/21/2020 │ 1.687      │
# │ 8464 │ 2/24/2020 │ 1.613      │
# │ 8465 │ 2/25/2020 │ 1.569      │
# │ 8466 │ 2/26/2020 │ 1.499      │
# │ 8467 │ 2/27/2020 │ 1.489      │
# │ 8468 │ 2/28/2020 │ 1.491      │
# │ 8469 │ 3/2/2020  │ 1.529      │
# │ 8470 │ 3/3/2020  │ 1.533      │

# %%
df = join(spot, futures, kind=:inner, on=:Date)
# Out:
# 8446×3 DataFrame
# │ Row  │ Date      │ HO-Spot │ HO-Futures │
# │      │ String    │ Float64 │ Float64    │
# ├──────┼───────────┼─────────┼────────────┤
# │ 1    │ 6/2/1986  │ 0.402   │ 0.378      │
# │ 2    │ 6/3/1986  │ 0.393   │ 0.38       │
# │ 3    │ 6/4/1986  │ 0.378   │ 0.358      │
# │ 4    │ 6/5/1986  │ 0.39    │ 0.374      │
# │ 5    │ 6/6/1986  │ 0.385   │ 0.372      │
# │ 6    │ 6/9/1986  │ 0.373   │ 0.366      │
# │ 7    │ 6/10/1986 │ 0.365   │ 0.36       │
# │ 8    │ 6/11/1986 │ 0.389   │ 0.384      │
# │ 9    │ 6/12/1986 │ 0.394   │ 0.394      │
# │ 10   │ 6/13/1986 │ 0.398   │ 0.397      │
# ⋮
# │ 8436 │ 2/10/2020 │ 1.581   │ 1.613      │
# │ 8437 │ 2/12/2020 │ 1.647   │ 1.676      │
# │ 8438 │ 2/13/2020 │ 1.651   │ 1.681      │
# │ 8439 │ 2/14/2020 │ 1.669   │ 1.698      │
# │ 8440 │ 2/17/2020 │ 1.669   │ 1.698      │
# │ 8441 │ 2/18/2020 │ 1.644   │ 1.672      │
# │ 8442 │ 2/19/2020 │ 1.667   │ 1.707      │
# │ 8443 │ 2/20/2020 │ 1.657   │ 1.698      │
# │ 8444 │ 2/21/2020 │ 1.65    │ 1.687      │
# │ 8445 │ 2/24/2020 │ 1.575   │ 1.613      │
# │ 8446 │ 2/25/2020 │ 1.529   │ 1.569      │

# %%
DataFrames.rename!(df, [:date,:spot,:futures])
# Out:
# 8446×3 DataFrame
# │ Row  │ date      │ spot    │ futures │
# │      │ String    │ Float64 │ Float64 │
# ├──────┼───────────┼─────────┼─────────┤
# │ 1    │ 6/2/1986  │ 0.402   │ 0.378   │
# │ 2    │ 6/3/1986  │ 0.393   │ 0.38    │
# │ 3    │ 6/4/1986  │ 0.378   │ 0.358   │
# │ 4    │ 6/5/1986  │ 0.39    │ 0.374   │
# │ 5    │ 6/6/1986  │ 0.385   │ 0.372   │
# │ 6    │ 6/9/1986  │ 0.373   │ 0.366   │
# │ 7    │ 6/10/1986 │ 0.365   │ 0.36    │
# │ 8    │ 6/11/1986 │ 0.389   │ 0.384   │
# │ 9    │ 6/12/1986 │ 0.394   │ 0.394   │
# │ 10   │ 6/13/1986 │ 0.398   │ 0.397   │
# ⋮
# │ 8436 │ 2/10/2020 │ 1.581   │ 1.613   │
# │ 8437 │ 2/12/2020 │ 1.647   │ 1.676   │
# │ 8438 │ 2/13/2020 │ 1.651   │ 1.681   │
# │ 8439 │ 2/14/2020 │ 1.669   │ 1.698   │
# │ 8440 │ 2/17/2020 │ 1.669   │ 1.698   │
# │ 8441 │ 2/18/2020 │ 1.644   │ 1.672   │
# │ 8442 │ 2/19/2020 │ 1.667   │ 1.707   │
# │ 8443 │ 2/20/2020 │ 1.657   │ 1.698   │
# │ 8444 │ 2/21/2020 │ 1.65    │ 1.687   │
# │ 8445 │ 2/24/2020 │ 1.575   │ 1.613   │
# │ 8446 │ 2/25/2020 │ 1.529   │ 1.569   │

# %%
#n = 500;
#spot = cumsum(randn(n));
#α = .25
#β = 2.46
#σ = 2.0
#z = randn(n) * σ
#futures = α .+ β .* spot .+ z;

# %%
fobs = 8470
sobs = 8497
# Out:
# 8497

# %%
StatsPlots.plot(df["futures"])
StatsPlots.plot!(df["spot"])

# %%
ΔS = diff(df["spot"])
ΔF = diff(df["futures"]);

# %%
ΔS;

# %%
ΔF;

# %%
X = ones(fobs-1,2)
X[:,2] .= ΔF
y = ones(sobs-1,2)
y[:,2] .= ΔS
# Out:
# UndefVarError: ΔF not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[17]:2
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
#coefs = StatsKit.MultivariateStats.llsq(ΔF, ΔS; bias=false)
#coefs[2]
#GLM.lm(@formula(spot ~ futures),df[1:60,:])

# %%
M = 25
hedgeratios = zeros(M)
ibeg = 61
iend = 121
ii = 1
step = 30

for i=1:step:(step*M)
    model = GLM.lm(@formula(spot ~ futures), df[ibeg:iend, :])
    hedgeratios[ii] = coef(model)[2]
    ibeg += step
    iend += step
    ii += 1
end

# %%
model = GLM.lm(@formula(spot ~ futures), df[1:60, :])
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}}}}, Matrix{Float64}}
#
# spot ~ 1 + futures
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  0.044306   0.0104833   4.23    <1e-04  0.0233214  0.0652907
# futures      0.875631   0.0279238  31.36    <1e-37  0.819735   0.931526
# ────────────────────────────────────────────────────────────────────────

# %%
coef(model)[2]
# Out:
# 0.8756307867830835

# %%
#test = 61
#nest = 121

#hest = GLM.lm(@formula(spot ~ futures),df[test:nest,:])
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}}}}, Matrix{Float64}}
#
# spot ~ 1 + futures
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────────
#                   Coef.  Std. Error      t  Pr(>|t|)   Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────────
# (Intercept)  0.00574537   0.0100454   0.57    0.5695  -0.0143554  0.0258462
# futures      0.954305     0.0239767  39.80    <1e-43   0.906327   1.00228
# ───────────────────────────────────────────────────────────────────────────

# %%
#hest;

# %%
StatsPlots.plot(hedgeratios)

# %%
hedgeratios[1:25]
# Out:
# 25-element Vector{Float64}:
#  0.9543045478615719
#  1.0079536636736794
#  1.006227591838438
#  1.0051341559834994
#  1.0701171247648895
#  1.0436302949648875
#  0.826646449248349
#  1.0017104033215376
#  1.0347114712853678
#  0.8614958232288107
#  0.9663263653419821
#  0.8222751661118903
#  1.032695175780267
#  1.1541617530408175
#  1.564744549938692
#  0.999368037388585
#  1.0485770967869794
#  1.0765595059828876
#  1.1195643658888526
#  1.0192231999086778
#  0.9413399774710353
#  0.8843775141842269
#  0.8733034720173548
#  0.8208043452175107
#  1.0201097639849093

# %%
df["spot"]
# Out:
# 8446-element Vector{Float64}:
#  0.402
#  0.393
#  0.378
#  0.39
#  0.385
#  0.373
#  0.365
#  0.389
#  0.394
#  0.398
#  0.379
#  0.374
#  0.376
#  ⋮
#  1.612
#  1.581
#  1.647
#  1.651
#  1.669
#  1.669
#  1.644
#  1.667
#  1.657
#  1.65
#  1.575
#  1.529

# %%
using DataFrames
logdf = DataFrame(logspot = log.(df["spot"]), logfutures = log.(df["futures"]))
# Out:
# 8446×2 DataFrame
# │ Row  │ logspot   │ logfutures │
# │      │ Float64   │ Float64    │
# ├──────┼───────────┼────────────┤
# │ 1    │ -0.911303 │ -0.972861  │
# │ 2    │ -0.933946 │ -0.967584  │
# │ 3    │ -0.972861 │ -1.02722   │
# │ 4    │ -0.941609 │ -0.983499  │
# │ 5    │ -0.954512 │ -0.988861  │
# │ 6    │ -0.986177 │ -1.00512   │
# │ 7    │ -1.00786  │ -1.02165   │
# │ 8    │ -0.944176 │ -0.957113  │
# │ 9    │ -0.931404 │ -0.931404  │
# │ 10   │ -0.921303 │ -0.923819  │
# ⋮
# │ 8436 │ 0.458058  │ 0.478096   │
# │ 8437 │ 0.498955  │ 0.51641    │
# │ 8438 │ 0.501381  │ 0.519389   │
# │ 8439 │ 0.512225  │ 0.529451   │
# │ 8440 │ 0.512225  │ 0.529451   │
# │ 8441 │ 0.497132  │ 0.514021   │
# │ 8442 │ 0.511026  │ 0.534737   │
# │ 8443 │ 0.505009  │ 0.529451   │
# │ 8444 │ 0.500775  │ 0.522952   │
# │ 8445 │ 0.454255  │ 0.478096   │
# │ 8446 │ 0.424614  │ 0.450438   │

# %%
ΔLS = diff(Logspot);
ΔLF = diff(Logfutures);

# %%
X = ones(fobs-1,2)
X[:,2] .= ΔLF
y = ones(sobs-1,2)
y[:,2] .= ΔLS
# Out:
# UndefVarError: ΔLF not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:2
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
M = 25
loghedgeratios = zeros(M)
ibeg = 61
iend = 121
ii = 1
step = 30

for i=1:step:(step*M)
    model = GLM.lm(@formula(logspot ~ logfutures), logdf[ibeg:iend, :])
    loghedgeratios[ii] = coef(model)[2]
    ibeg += step
    iend += step
    ii += 1
end

# %%
StatsPlots.plot(loghedgeratios)

# %%
loghedgeratios[1:25]
# Out:
# 25-element Vector{Float64}:
#  0.9840222065738958
#  1.0397159892700127
#  1.0154810509164105
#  1.0144820611759853
#  1.071450746733292
#  1.0390520032233037
#  0.8262558129444387
#  1.008158947171015
#  1.0389798882185763
#  0.8529130715149885
#  0.9545111438170445
#  0.7930940225486957
#  0.9759771251329987
#  1.1127055962233996
#  1.513311340816434
#  1.0086644562199367
#  1.0641292739099566
#  1.088541056801591
#  1.103601393228519
#  0.9943182204566321
#  0.9172221754066752
#  0.851177851051999
#  0.8670064226709917
#  0.8225552950956573
#  1.0346110704942901

# %%
StatsPlots.plot(futures[2])
StatsPlots.plot!(spot[2])
# Out:
# UndefVarError: futures not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[29]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
futures[:2]
# Out:
# UndefVarError: futures not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[30]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
GLM.lm(@formula(spot ~ futures),df[61:121,:])
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}}}}, Matrix{Float64}}
#
# spot ~ 1 + futures
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────────
#                   Coef.  Std. Error      t  Pr(>|t|)   Lower 95%  Upper 95%
# ───────────────────────────────────────────────────────────────────────────
# (Intercept)  0.00574537   0.0100454   0.57    0.5695  -0.0143554  0.0258462
# futures      0.954305     0.0239767  39.80    <1e-43   0.906327   1.00228
# ───────────────────────────────────────────────────────────────────────────

# %%
testpush=1
# Out:
# 1
